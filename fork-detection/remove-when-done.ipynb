# %%
import pandas as pd

# %%
df = pd.read_csv("/home/sv/fork_pattern.csv")

# %%
df.head(15)
# Out:
#     Unnamed: 0  snapshot_id  count_forks  mean_forks_per_month  \
# 0            0   31116507.0          4.0              0.400000
# 1            1   33121552.0          4.0              0.400000
# 2            2   39935554.0          4.0              0.400000
# 3            3   40001797.0          4.0              0.400000
# 4            4   43643182.0          4.0              0.400000
# 5            5   51311723.0          4.0              0.333333
# 6            6   51373372.0          2.0              0.166667
# 7            7   51509000.0          1.0              0.083333
# 8            8   51596086.0          2.0              0.166667
# 9            9   51751119.0          2.0              0.166667
# 10          10   51928656.0          1.0              0.083333
# 11          11   51931699.0          3.0              0.250000
# 12          12   51932652.0          6.0              0.500000
# 13          13   51941261.0          1.0              0.090909
# ...
