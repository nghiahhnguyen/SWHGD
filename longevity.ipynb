# %%
import csv
import gzip
from dateutil.parser import parse
from decimal import *
import pandas as pd
import gc
import os
from multiprocessing import Process
def calculate_longevity(name):
    info(name)
    cnt = 0
    snapshots = {}
    longevity = {}
    snapshot_id = 0
    for lines in pd.read_csv("/mnt/17volume/data/snapshot_revision_git.csv.gz.part" + name, chunksize=1000, encoding='utf-8', header=None):
        for line in lines.iterrows():
            #print(line[1])
            if cnt == 0 and name == 'aa':
                print("first process aa")
                cnt+=1
                continue
            try:    
                if line[1][2] == line[1][2]:
                    if line[1][0] not in snapshots:
                        if len(snapshots) > 0:
                            snapshots[snapshot_id].sort()
                            #print(len(snapshots[snapshot_id]))
                            if len(snapshots[snapshot_id]) > 1:
                                m = abs(int(snapshots[snapshot_id][-1]) - int(snapshots[snapshot_id][0]) )

                                #print(snapshot_id,' ', longevity[snapshot_id])
                                s  = pd.Series(longevity,index=longevity.keys())
                                df = pd.DataFrame({
                                    'snapshot_id':[snapshot_id], 
                                    'longevity':[m]
                                })
                                #print(df)
                                df.to_csv('/home/sv/longevity-' + name + '.csv.gz', compression = 'gzip', mode ='a', header=False, index=False)
                            del snapshots[snapshot_id]
                        del snapshots
                        gc.collect()
                        snapshots = {}
                        snapshot_id = line[1][0]
                        if snapshot_id is not None:
                            snapshots[snapshot_id] = [line[1][2]]
                    else:
                        snapshots[snapshot_id].append(line[1][2])
            except Exception as e:
                f = open("/home/sv/longevity_error.txt", "a")
                f.write("Project id: " + str(line[1][0]))
                f.write(", error: " + str(e) + "\n")
                with open('/home/sv/longevity_exception.csv', mode='a') as project_file:
                    project_writer = csv.writer(project_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    project_writer.writerow([line[1][0], line[1][2], line[1][3], line[1][1]])
                pass
def info(title):
    print(title)
    print('module name:', __name__)
    print('parent process:', os.getppid())
    print('process id:', os.getpid())
    
if __name__ == '__main__':
    p1 = Process(target=calculate_longevity, args = ('aa',))
    p1.start()
    p2 = Process(target=calculate_longevity, args = ('ab',))
    p2.start()
    p3 = Process(target=calculate_longevity, args = ('ac',))
    p3.start()  
    p4 = Process(target=calculate_longevity, args = ('ad',))
    p4.start()  
    p5 = Process(target=calculate_longevity, args = ('ae',))
    p5.start()
    p6 = Process(target=calculate_longevity, args = ('af',))
    p6.start()
# Out:
# aa
# ('module name:', '__main__')
# ('parent process:', 8746)
# ('process id:', 11679)
# ab
# ('module name:', '__main__')
# ('parent process:', 8746)
# ('process id:', 11684)
# first process aa
# ac
# ad
# ('module name:', '__main__')
# ('module name:', '__main__')
# ('parent process:', 8746)
# ('parent process:', 8746)
# ('process id:', 11693)
# ('process id:', 11698)
# ae
# ('module name:', '__main__')
# ('parent process:', 8746)
# af
# ('process id:', 11709)
# ('module name:', '__main__')
# ('parent process:', 8746)
# ('process id:', 11722)
# Process Process-21:
# Process Process-23:
# Process Process-20:
# Process Process-19:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "<ipython-input-5-a6d73c154207>", line 16, in calculate_longevity
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     for line in lines.iterrows():
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-a6d73c154207>", line 16, in calculate_longevity
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.py", line 846, in iterrows
#   File "<ipython-input-5-a6d73c154207>", line 15, in calculate_longevity
#     for line in lines.iterrows():
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.py", line 846, in iterrows
#     s = klass(v, index=columns, name=k)
#     for lines in pd.read_csv("/mnt/17volume/data/snapshot_revision_git.csv.gz.part" + name, chunksize=1000, encoding='utf-8', header=None):
#     s = klass(v, index=columns, name=k)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/io/common.py", line 73, in <lambda>
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 262, in __init__
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 264, in __init__
# Process Process-22:
#     raise_cast_failure=True)
#     data = SingleBlockManager(data, index, fastpath=True)
# Traceback (most recent call last):
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 582, in sanitize_array
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/managers.py", line 1481, in __init__
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#     self.run()
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/blocks.py", line 3088, in make_block
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     BaseIterator.next = lambda self: self.__next__()
#     self._target(*self._args, **self._kwargs)
#     subarr = _try_cast(data, True, dtype, copy, raise_cast_failure)
#     klass = get_block_type(values, dtype)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/io/parsers.py", line 1115, in __next__
#   File "<ipython-input-5-a6d73c154207>", line 16, in calculate_longevity
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/blocks.py", line 3053, in get_block_type
#     for line in lines.iterrows():
#     return self.get_chunk()
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 688, in _try_cast
#     elif is_categorical(values):
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.py", line 846, in iterrows
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/io/parsers.py", line 1173, in get_chunk
#     return self.read(nrows=size)
#     if maybe_castable(arr) and not copy and dtype is None:
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/common.py", line 291, in is_categorical
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/io/parsers.py", line 1154, in read
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/cast.py", line 843, in maybe_castable
#     s = klass(v, index=columns, name=k)
#     return isinstance(arr, ABCCategorical) or is_categorical_dtype(arr)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/common.py", line 602, in is_categorical_dtype
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 262, in __init__
#     return CategoricalDtype.is_dtype(arr_or_dtype)
#     raise_cast_failure=True)
#     return arr.dtype.name not in _POSSIBLY_CAST_DTYPES
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/base.py", line 101, in is_dtype
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 555, in sanitize_array
# Process Process-24:
#   File "/home/sv/.local/lib/python2.7/site-packages/numpy/core/_dtype.py", line 334, in _name_get
#     data = extract_array(data, extract_numpy=True)
# Traceback (most recent call last):
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/arrays.py", line 49, in extract_array
#     if np.issubdtype(dtype, np.flexible) and not _isunsized(dtype):
#     ABCDataFrame, np.dtype)):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/generic.py", line 9, in _check
#   File "/home/sv/.local/lib/python2.7/site-packages/numpy/core/numerictypes.py", line 392, in issubdtype
#     self.run()
#     if isinstance(obj, (ABCIndexClass, ABCSeries)):
#     return getattr(inst, attr, '_typ') in comp
# KeyboardInterrupt
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
# KeyboardInterrupt
#     if not issubclass_(arg1, generic):
#     self._target(*self._args, **self._kwargs)
#   File "/home/sv/.local/lib/python2.7/site-packages/numpy/core/numerictypes.py", line 328, in issubclass_
#   File "<ipython-input-5-a6d73c154207>", line 15, in calculate_longevity
#     return issubclass(arg1, arg2)
#     for lines in pd.read_csv("/mnt/17volume/data/snapshot_revision_git.csv.gz.part" + name, chunksize=1000, encoding='utf-8', header=None):
# KeyboardInterrupt
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/io/common.py", line 73, in <lambda>
#     BaseIterator.next = lambda self: self.__next__()
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/io/parsers.py", line 1115, in __next__
#     return self.get_chunk()
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/io/parsers.py", line 1173, in get_chunk
#     return self.read(nrows=size)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/io/parsers.py", line 1154, in read
#     self.run()
#     df = DataFrame(col_dict, columns=columns, index=index)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.py", line 392, in __init__
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-a6d73c154207>", line 16, in calculate_longevity
#     mgr = init_dict(data, index, columns, dtype=dtype)
#     for line in lines.iterrows():
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 177, in init_dict
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.py", line 846, in iterrows
#     arrays = Series(data, index=columns, dtype=object)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 207, in __init__
#     s = klass(v, index=columns, name=k)
#     data, index = self._init_dict(data, index, dtype)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 262, in __init__
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 304, in _init_dict
#     df = DataFrame(col_dict, columns=columns, index=index)
#     s = Series(values, index=keys, dtype=dtype)
#     raise_cast_failure=True)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.py", line 392, in __init__
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 582, in sanitize_array
#     subarr = _try_cast(data, True, dtype, copy, raise_cast_failure)
#     mgr = init_dict(data, index, columns, dtype=dtype)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 697, in _try_cast
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 212, in init_dict
#     subarr = maybe_cast_to_datetime(arr, dtype)
#     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/cast.py", line 1067, in maybe_cast_to_datetime
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 56, in arrays_to_mgr
#     value = maybe_infer_to_datetimelike(value)
#     arrays = _homogenize(arrays, index, dtype)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/cast.py", line 874, in maybe_infer_to_datetimelike
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 277, in _homogenize
#     if not is_list_like(v):
#     raise_cast_failure=False)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/inference.py", line 295, in is_list_like
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 582, in sanitize_array
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 169, in __init__
#     and not isinstance(obj, string_and_binary_types)
#     subarr = _try_cast(data, True, dtype, copy, raise_cast_failure)
#     index = ensure_index(index)
# KeyboardInterrupt
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/indexes/base.py", line 5378, in ensure_index
#     return Index(index_like)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/indexes/base.py", line 324, in __new__
#     elif is_period_dtype(data) and not is_object_dtype(dtype):
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/common.py", line 533, in is_period_dtype
#     return PeriodDtype.is_dtype(arr_or_dtype)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/dtypes.py", line 847, in is_dtype
#     return super(PeriodDtype, cls).is_dtype(dtype)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/base.py", line 112, in is_dtype
#     return cls.construct_from_string(dtype) is not None
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/dtypes.py", line 792, in construct_from_string
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 704, in _try_cast
#     from pandas.tseries.offsets import DateOffset
#     elif not is_extension_type(subarr):
# KeyboardInterrupt
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/common.py", line 1697, in is_extension_type
#     elif is_datetime64tz_dtype(arr):
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/common.py", line 469, in is_datetime64tz_dtype
#     return DatetimeTZDtype.is_dtype(arr_or_dtype)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/base.py", line 98, in is_dtype
#     dtype = getattr(dtype, 'dtype', dtype)
# KeyboardInterrupt
