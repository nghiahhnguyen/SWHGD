# %%
import csv
import gzip
from dateutil.parser import parse
from decimal import *
import pandas as pd
import gc
import os
from multiprocessing import Process
def calculate_cycle_times(name):
    info(name)
    cnt = 0
    snapshots = {}
    cycle_times = {}
    snapshot_id = 0
    for lines in pd.read_csv("/mnt/17volume/data/snapshot_revision_git.csv.gz.part" + name, chunksize=1000, encoding='utf-8', header=None):
        for line in lines.iterrows():
            #print(line[1])
            if cnt == 0 and name == 'aa':
                print("first process aa")
                cnt+=1
                continue
            try:
                if line[1][4] == line[1][4]:
                    if line[1][0] not in snapshots:
                        if len(snapshots) > 0:
                            snapshots[snapshot_id].sort()
                            #print(len(snapshots[snapshot_id]))                            
                            tmp = []
                            if len(snapshots[snapshot_id]) > 1:
                                for i in range(len(snapshots[snapshot_id])-1):
                                    tmp.append(abs(int(snapshots[snapshot_id][i]) - int(snapshots[snapshot_id][i+1])))
                                m = sum(tmp)/len(tmp)
                                cycle_times[snapshot_id] = m
                                #print(snapshot_id,' ', cycle_times[snapshot_id])
                                s  = pd.Series(cycle_times,index=cycle_times.keys())
                                df = pd.DataFrame({
                                    'snapshot_id':[snapshot_id], 
                                    'cycle_times':[m]
                                })
                                #print(df)
                                df.to_csv('/home/sv/cycle_time_release_' + name + '.csv.gz', compression = 'gzip', mode ='a', header=False, index=False)
                            del snapshots[snapshot_id]
                        del snapshots
                        gc.collect()
                        snapshots = {}
                        snapshot_id = line[1][0]
                        if snapshot_id is not None:
                            snapshots[snapshot_id] = [line[1][4]]
                    else:
                        snapshots[snapshot_id].append(line[1][4])
            except Exception as e:
                f = open("/home/sv/cycle_time_error.txt", "a")
                f.write("Project id: " + str(line[1][0]))
                f.write(", error: " + str(e) + "\n")
                with open('/home/sv/cycle_time_exception.csv', mode='a') as project_file:
                    project_writer = csv.writer(project_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    project_writer.writerow([line[1][0], line[1][1], line[1][2], line[1][3], line[1][4]])
                pass
def info(title):
    print(title)
    print('module name:', __name__)
    print('parent process:', os.getppid())
    print('process id:', os.getpid())
    
if __name__ == '__main__':
    p1 = Process(target=calculate_cycle_times, args = ('aa',))
    p1.start()
    p2 = Process(target=calculate_cycle_times, args = ('ab',))
    p2.start()
    p3 = Process(target=calculate_cycle_times, args = ('ac',))
    p3.start()  
    p4 = Process(target=calculate_cycle_times, args = ('ad',))
    p4.start()  
    p5 = Process(target=calculate_cycle_times, args = ('ae',))
    p5.start()
    p6 = Process(target=calculate_cycle_times, args = ('af',))
    p6.start()
# Out:
# aa
# ab
# ac
# ae
# ad
# af
# ('module name:', '__main__')
# ('module name:', '__main__')
# ('module name:', '__main__')
# ('parent process:', 9852)
# ('module name:', '__main__')
# ('module name:', '__main__')
# ('parent process:', 9852)
# ('module name:', '__main__')
# ('parent process:', 9852)
# ('parent process:', 9852)
# ('process id:', 13344)
# ('parent process:', 9852)
# ('process id:', 13349)
# ('parent process:', 9852)
# ('process id:', 13339)
# ('process id:', 13343)
# ('process id:', 13352)
# ('process id:', 13340)
# first process aa
# Process Process-25:
# Process Process-27:
# Process Process-26:
# Process Process-30:
# Traceback (most recent call last):
# Process Process-29:
# Process Process-28:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-42f8671f848b>", line 16, in calculate_cycle_times
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-42f8671f848b>", line 16, in calculate_cycle_times
#     for line in lines.iterrows():
#     self.run()
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-42f8671f848b>", line 16, in calculate_cycle_times
#   File "<ipython-input-5-42f8671f848b>", line 16, in calculate_cycle_times
#     for line in lines.iterrows():
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "<ipython-input-5-42f8671f848b>", line 23, in calculate_cycle_times
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.py", line 846, in iterrows
#     for line in lines.iterrows():
#     self._target(*self._args, **self._kwargs)
#     s = klass(v, index=columns, name=k)
#     if line[1][4] == line[1][4]:
#     for line in lines.iterrows():
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.py", line 846, in iterrows
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.py", line 846, in iterrows
#   File "<ipython-input-5-42f8671f848b>", line 16, in calculate_cycle_times
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 262, in __init__
#     s = klass(v, index=columns, name=k)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.py", line 846, in iterrows
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 868, in __getitem__
#     s = klass(v, index=columns, name=k)
#     for line in lines.iterrows():
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 264, in __init__
#     result = self.index.get_value(self, key)
#     raise_cast_failure=True)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 262, in __init__
#     s = klass(v, index=columns, name=k)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.py", line 846, in iterrows
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/indexes/base.py", line 4369, in get_value
#     data = SingleBlockManager(data, index, fastpath=True)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 262, in __init__
#     raise_cast_failure=True)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/managers.py", line 1481, in __init__
#     s = klass(v, index=columns, name=k)
#     s = com.values_from_object(series)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 582, in sanitize_array
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 582, in sanitize_array
#     subarr = _try_cast(data, True, dtype, copy, raise_cast_failure)
#     block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#     raise_cast_failure=True)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 262, in __init__
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/blocks.py", line 3088, in make_block
#   File "pandas/_libs/lib.pyx", line 84, in pandas._libs.lib.values_from_object
#     subarr = _try_cast(data, True, dtype, copy, raise_cast_failure)
#     raise_cast_failure=True)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 694, in _try_cast
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 697, in _try_cast
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 674, in sanitize_array
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/series.py", line 494, in get_values
#     if is_integer_dtype(dtype):
#     klass = get_block_type(values, dtype)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.py", line 674, in sanitize_array
#     return self._data.get_values()
#     subarr = maybe_cast_to_datetime(arr, dtype)
#     inferred = lib.infer_dtype(subarr, skipna=False)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/blocks.py", line 3053, in get_block_type
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/common.py", line 920, in is_integer_dtype
#     inferred = lib.infer_dtype(subarr, skipna=False)
#     arr_or_dtype, classes_and_not_datetimelike(np.integer))
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/cast.py", line 957, in maybe_cast_to_datetime
#   File "pandas/_libs/lib.pyx", line 1242, in pandas._libs.lib.infer_dtype
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/common.py", line 1861, in _is_dtype_type
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/managers.py", line 1558, in get_values
#     elif is_categorical(values):
#   File "pandas/_libs/lib.pyx", line 1242, in pandas._libs.lib.infer_dtype
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/common.py", line 291, in is_categorical
#     return condition(type(None))
#   File "pandas/_libs/lib.pyx", line 1093, in pandas._libs.lib._try_infer_map
#     return np.array(self._block.to_dense(), copy=False)
#     from pandas.core.tools.timedeltas import to_timedelta
#   File "pandas/_libs/lib.pyx", line 1093, in pandas._libs.lib._try_infer_map
#     return isinstance(arr, ABCCategorical) or is_categorical_dtype(arr)
#   File "/home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/blocks.py", line 185, in to_dense
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/sv/.local/lib/python2.7/site-packages/numpy/core/_dtype.py", line 319, in _name_get
#   File "/home/sv/.local/lib/python2.7/site-packages/numpy/core/_dtype.py", line 334, in _name_get
# KeyboardInterrupt
#     def _name_get(dtype):
#     return self.values.view()
# KeyboardInterrupt
#     if np.issubdtype(dtype, np.flexible) and not _isunsized(dtype):
# KeyboardInterrupt
# KeyboardInterrupt
