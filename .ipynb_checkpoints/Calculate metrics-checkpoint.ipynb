# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
projectReleaseDate_g = pd.read_csv("/mnt/17volume/data/snapshot_release_git_linh.csv")
projectReleaseDate_o = pd.read_csv("/mnt/17volume/data/snapshot_release_other_linh.csv")
projectReleaseDate = pd.concat([projectReleaseDate_g, projectReleaseDate_o]).drop_duplicates()
projectReleaseDate.info()
projectReleaseDate.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1185 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   snapshot_id  1185 non-null   int64
#  1   release_id   1185 non-null   object
#  2   date         1185 non-null   int64
#  3   author       1185 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 46.3+ KB
#    snapshot_id                                release_id        date  author
# 0     10000002  ad50d6158d9db230c8d0865b332d7b84f0031d85  1354119368   43455
# 1     10000002  2f573123f570b29c55c903daee45728dea568611  1353621146   43455
# 2     10000002  99b403c381a05cb12867f31d1f1c84257bace0e3  1353620363   43455
# 3     10000002  445992fd94e836470065bf02dabbcfbb36eda8f9  1353029061   43455
# 4     10000002  689ca7d6ded7cfba285d0e6cbae1194a6b10c858  1352075828  207817

# %%
projectReleaseDate['lagged'] = projectReleaseDate.groupby(['snapshot_id'])['date'].shift(1)
projectReleaseDate = projectReleaseDate[projectReleaseDate['lagged'].notnull()]
projectReleaseDate['mean_cycle_time'] = projectReleaseDate['lagged'] - projectReleaseDate['date']
projectReleaseDate.head()
# Out:
#    snapshot_id                                release_id        date  author  \
# 1     10000002  2f573123f570b29c55c903daee45728dea568611  1353621146   43455
# 2     10000002  99b403c381a05cb12867f31d1f1c84257bace0e3  1353620363   43455
# 3     10000002  445992fd94e836470065bf02dabbcfbb36eda8f9  1353029061   43455
# 4     10000002  689ca7d6ded7cfba285d0e6cbae1194a6b10c858  1352075828  207817
# 5     10000002  c4da0906dbfa90c098b0c01ff57b49e09cb55af2  1352075650  207817
#
#          lagged  mean_cycle_time
# 1  1.354119e+09         498222.0
# 2  1.353621e+09            783.0
# 3  1.353620e+09         591302.0
# 4  1.353029e+09         953233.0
# 5  1.352076e+09            178.0

# %%
projectCycleTime = projectReleaseDate[['snapshot_id','mean_cycle_time']].groupby('snapshot_id', as_index=False).mean()
projectCycleTime.to_csv("mean_cycle_time_metrics.csv", encoding='utf-8', index=False)
projectReleaseDate.info()
projectCycleTime.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1050 entries, 1 to 999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   snapshot_id      1050 non-null   int64
#  1   release_id       1050 non-null   object
#  2   date             1050 non-null   int64
#  3   author           1050 non-null   int64
#  4   lagged           1050 non-null   float64
#  5   mean_cycle_time  1050 non-null   float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 57.4+ KB
#    snapshot_id  mean_cycle_time
# 0      1000047     2.262263e+06
# 1      1000048     5.072456e+06
# 2      1000174     1.074825e+07
# 3     10000002     4.087436e+05
# 4     10000080     4.618572e+06

# %%
projectGitMetrics = pd.read_csv("/mnt/17volume/data/project-git-metrics.csv")
projectOtherMetrics = pd.read_csv("/mnt/17volume/data/project-other-metrics.csv")

projectMetrics = pd.concat([projectGitMetrics, projectOtherMetrics]).drop_duplicates()
projectMetrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1079 entries, 0 to 95
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   snapshot_id         1079 non-null   int64
#  1   total_revisions     1079 non-null   int64
#  2   total_authors       1079 non-null   int64
#  3   revision_frequency  1079 non-null   float64
#  4   author_frequency    1079 non-null   float64
# dtypes: float64(2), int64(3)
# memory usage: 50.6 KB

# %%
# longevity
rawData1 = pd.read_csv("/mnt/17volume/data/snapshot_revision_git_bao.csv")
rawData2 = pd.read_csv("/mnt/17volume/data/snapshot_revision_other_bao.csv")
rawData = pd.concat([rawData1, rawData2])
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146705 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   snapshot_id  146705 non-null  int64
#  1   id           146705 non-null  object
#  2   date         146705 non-null  int64
#  3   author       146705 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 5.6+ MB

# %%
table = rawData.sort_values(['snapshot_id', 'date'], ascending=[True, True])

table2 = table[['snapshot_id','date']]

table3 = table2.groupby(['snapshot_id'], as_index=True)['date'].agg(['first', 'last']).reset_index()

table3['longevity'] = table3['last'] - table3['first']

# table3['longevity'] = pd.to_timedelta(table3['longevity'], unit='ms')

longevityMetric = table3[['snapshot_id','longevity']]

longevityMetric.to_csv("longevity_metrics.csv", encoding='utf-8', index=False)

projectMetrics = pd.merge(projectMetrics, longevityMetric, on='snapshot_id', how='outer')

projectMetrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1079 entries, 0 to 1078
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   snapshot_id         1079 non-null   int64
#  1   total_revisions     1079 non-null   int64
#  2   total_authors       1079 non-null   int64
#  3   revision_frequency  1079 non-null   float64
#  4   author_frequency    1079 non-null   float64
#  5   longevity           1079 non-null   int64
# dtypes: float64(2), int64(4)
# memory usage: 59.0 KB

# %%
projectMetrics = pd.merge(projectMetrics, projectCycleTime, on='snapshot_id', how='outer')

projectMetrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1079 entries, 0 to 1078
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   snapshot_id         1079 non-null   int64
#  1   total_revisions     1079 non-null   int64
#  2   total_authors       1079 non-null   int64
#  3   revision_frequency  1079 non-null   float64
#  4   author_frequency    1079 non-null   float64
#  5   longevity           1079 non-null   int64
#  6   mean_cycle_time     111 non-null    float64
# dtypes: float64(3), int64(4)
# memory usage: 67.4 KB

# %%
projectMetrics.plot(kind='scatter',x='total_revisions', y='longevity',color='red')
plt.show()

# %%
projectMetrics.info()
del projectMetrics['snapshot_id']
pearsonCorr = projectMetrics.corr(method='pearson')

pearsonCorr.to_csv("pearson_correlation_coefficient.csv", encoding='utf-8', index=True)

print(pearsonCorr)

sbplot = sb.heatmap(pearsonCorr, 
            xticklabels=pearsonCorr.columns,
            yticklabels=pearsonCorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=1)

sbplot.get_figure().savefig("corr.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1079 entries, 0 to 1078
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   snapshot_id         1079 non-null   int64
#  1   total_revisions     1079 non-null   int64
#  2   total_authors       1079 non-null   int64
#  3   revision_frequency  1079 non-null   float64
#  4   author_frequency    1079 non-null   float64
#  5   longevity           1079 non-null   int64
#  6   mean_cycle_time     111 non-null    float64
# dtypes: float64(3), int64(4)
# memory usage: 67.4 KB
#                     total_revisions  total_authors  revision_frequency  \
# total_revisions            1.000000       0.947646            0.260570
# total_authors              0.947646       1.000000            0.241901
# revision_frequency         0.260570       0.241901            1.000000
# author_frequency           0.464420       0.471406            0.456402
# longevity                  0.374827       0.408939            0.000296
# mean_cycle_time            0.021851       0.024579           -0.014832
#
#                     author_frequency  longevity  mean_cycle_time
# total_revisions             0.464420   0.374827         0.021851
# total_authors               0.471406   0.408939         0.024579
# revision_frequency          0.456402   0.000296        -0.014832
# author_frequency            1.000000   0.114932         0.046556
# longevity                   0.114932   1.000000         0.020576
# mean_cycle_time             0.046556   0.020576         1.000000

# %%
projectMetrics2 = projectMetrics[projectMetrics['mean_cycle_time'].notnull()]
projectMetrics2.info()
pearsonCorr = projectMetrics2.corr(method='pearson')

pearsonCorr.to_csv("/home/sv/fork_health_risk.csv", encoding='utf-8', index=True)

print(pearsonCorr)

sbplot = sb.heatmap(pearsonCorr, 
            xticklabels=pearsonCorr.columns,
            yticklabels=pearsonCorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=1)

sbplot.get_figure().savefig("corr.png")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a054955fb73> in <module>()
# ----> 1 projectMetrics2 = projectMetrics[projectMetrics['mean_cycle_time'].notnull()]
#       2 projectMetrics2.info()
#       3 pearsonCorr = projectMetrics2.corr(method='pearson')
#       4
#       5 pearsonCorr.to_csv("/home/sv/fork_health_risk.csv", encoding='utf-8', index=True)
#
# NameError: name 'projectMetrics' is not defined

# %%
df = pd.read_csv('/home/sv/fork_health_risk.csv')
pearsonCorr= df.corr(method ='kendall')
sbplot = sb.heatmap(pearsonCorr, 
            xticklabels=pearsonCorr.columns,
            yticklabels=pearsonCorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=1)

sbplot.get_figure().savefig("corr.png")
# Out:
#                             fork_counts  year_fork_mean  month_fork_mean  \
# fork_counts                    1.000000        0.999949         0.531109
# year_fork_mean                 0.999949        1.000000         0.531161
# month_fork_mean                0.531109        0.531161         1.000000
# week_fork_mean                 0.095779        0.095829         0.596063
# month_with_fork_counts         0.642532        0.642475         0.079705
# week_with_fork_counts          0.649876        0.649821         0.105573
# steady_month                   0.050808        0.050811         0.045685
# steady_week                         NaN             NaN              NaN
# commit_counts                  0.502465        0.502505         0.286503
# contributor_counts             0.565214        0.565253         0.320741
# daily_commit_frequency         0.497154        0.497196         0.286955
# weekly_commit_frequency        0.454948        0.454990         0.252276
# monthly_commit_frequency       0.359139        0.359185         0.183784
# daily_contributor_counts       0.014552        0.014553         0.018002
# weekly_contributor_counts      0.025716        0.025720         0.036068
# monthly_contributor_counts     0.044925        0.044938         0.032884
#
#                             week_fork_mean  month_with_fork_counts  \
# fork_counts                       0.095779                0.642532
# year_fork_mean                    0.095829                0.642475
# month_fork_mean                   0.596063                0.079705
# week_fork_mean                    1.000000               -0.370524
# month_with_fork_counts           -0.370524                1.000000
# week_with_fork_counts            -0.361383                0.962867
# steady_month                      0.034663                0.060330
# steady_week                            NaN                     NaN
# commit_counts                    -0.001088                0.429575
# contributor_counts                0.012937                0.467608
# daily_commit_frequency           -0.002068                0.421602
# weekly_commit_frequency          -0.022001                0.396859
# monthly_commit_frequency         -0.046344                0.330084
# daily_contributor_counts          0.012445               -0.004044
# weekly_contributor_counts         0.033261                0.007086
# monthly_contributor_counts       -0.014444                0.033685
#
#                             week_with_fork_counts  steady_month  steady_week  \
# fork_counts                              0.649876      0.050808          NaN
# year_fork_mean                           0.649821      0.050811          NaN
# month_fork_mean                          0.105573      0.045685          NaN
# week_fork_mean                          -0.361383      0.034663          NaN
# month_with_fork_counts                   0.962867      0.060330          NaN
# week_with_fork_counts                    1.000000      0.058274          NaN
# steady_month                             0.058274      1.000000          NaN
# steady_week                                   NaN           NaN          1.0
# commit_counts                            0.429057      0.040960          NaN
# contributor_counts                       0.466170      0.043638          NaN
# daily_commit_frequency                   0.421403      0.040315          NaN
# weekly_commit_frequency                  0.397127      0.035476          NaN
# monthly_commit_frequency                 0.330764      0.026438          NaN
# daily_contributor_counts                -0.004450     -0.000678          NaN
# weekly_contributor_counts                0.006627     -0.002311          NaN
# monthly_contributor_counts               0.035790     -0.010370          NaN
#
#                             commit_counts  contributor_counts  \
# fork_counts                      0.502465            0.565214
# year_fork_mean                   0.502505            0.565253
# month_fork_mean                  0.286503            0.320741
# week_fork_mean                  -0.001088            0.012937
# month_with_fork_counts           0.429575            0.467608
# week_with_fork_counts            0.429057            0.466170
# steady_month                     0.040960            0.043638
# steady_week                           NaN                 NaN
# commit_counts                    1.000000            0.654007
# contributor_counts               0.654007            1.000000
# daily_commit_frequency           0.691077            0.563723
# weekly_commit_frequency          0.614438            0.522220
# monthly_commit_frequency         0.486215            0.428862
# daily_contributor_counts         0.017597            0.011082
# weekly_contributor_counts        0.024169            0.002790
# monthly_contributor_counts       0.034985           -0.013161
#
#                             daily_commit_frequency  weekly_commit_frequency  \
# fork_counts                               0.497154                 0.454948
# year_fork_mean                            0.497196                 0.454990
# month_fork_mean                           0.286955                 0.252276
# week_fork_mean                           -0.002068                -0.022001
# month_with_fork_counts                    0.421602                 0.396859
# week_with_fork_counts                     0.421403                 0.397127
# steady_month                              0.040315                 0.035476
# steady_week                                    NaN                      NaN
# commit_counts                             0.691077                 0.614438
# contributor_counts                        0.563723                 0.522220
# daily_commit_frequency                    1.000000                 0.857374
# weekly_commit_frequency                   0.857374                 1.000000
# monthly_commit_frequency                  0.685530                 0.782364
# daily_contributor_counts                  0.028111                 0.026406
# weekly_contributor_counts                 0.079674                 0.089966
# monthly_contributor_counts                0.212859                 0.254028
#
#                             monthly_commit_frequency  \
# fork_counts                                 0.359139
# year_fork_mean                              0.359185
# month_fork_mean                             0.183784
# week_fork_mean                             -0.046344
# month_with_fork_counts                      0.330084
# week_with_fork_counts                       0.330764
# steady_month                                0.026438
# steady_week                                      NaN
# commit_counts                               0.486215
# contributor_counts                          0.428862
# daily_commit_frequency                      0.685530
# weekly_commit_frequency                     0.782364
# monthly_commit_frequency                    1.000000
# daily_contributor_counts                    0.019570
# weekly_contributor_counts                   0.066678
# monthly_contributor_counts                  0.299161
#
#                             daily_contributor_counts  \
# fork_counts                                 0.014552
# year_fork_mean                              0.014553
# month_fork_mean                             0.018002
# week_fork_mean                              0.012445
# month_with_fork_counts                     -0.004044
# week_with_fork_counts                      -0.004450
# steady_month                               -0.000678
# steady_week                                      NaN
# commit_counts                               0.017597
# contributor_counts                          0.011082
# daily_commit_frequency                      0.028111
# weekly_commit_frequency                     0.026406
# monthly_commit_frequency                    0.019570
# daily_contributor_counts                    1.000000
# weekly_contributor_counts                   0.292822
# monthly_contributor_counts                  0.064539
#
#                             weekly_contributor_counts  \
# fork_counts                                  0.025716
# year_fork_mean                               0.025720
# month_fork_mean                              0.036068
# week_fork_mean                               0.033261
# month_with_fork_counts                       0.007086
# week_with_fork_counts                        0.006627
# steady_month                                -0.002311
# steady_week                                       NaN
# commit_counts                                0.024169
# contributor_counts                           0.002790
# daily_commit_frequency                       0.079674
# weekly_commit_frequency                      0.089966
# monthly_commit_frequency                     0.066678
# daily_contributor_counts                     0.292822
# weekly_contributor_counts                    1.000000
# monthly_contributor_counts                   0.226772
#
#                             monthly_contributor_counts
# fork_counts                                   0.044925
# year_fork_mean                                0.044938
# month_fork_mean                               0.032884
# week_fork_mean                               -0.014444
# month_with_fork_counts                        0.033685
# week_with_fork_counts                         0.035790
# steady_month                                 -0.010370
# steady_week                                        NaN
# commit_counts                                 0.034985
# contributor_counts                           -0.013161
# daily_commit_frequency                        0.212859
# weekly_commit_frequency                       0.254028
# monthly_commit_frequency                      0.299161
# daily_contributor_counts                      0.064539
# weekly_contributor_counts                     0.226772
# monthly_contributor_counts                    1.000000
