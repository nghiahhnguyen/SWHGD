# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
cnt = 0

snapshots = {}
longevity = {}
snapshot_id = 0
for lines in pd.read_csv("/mnt/17volume/data/snapshot_revision_git.csv.gz", compression='gzip', chunksize=1000, encoding='utf-8', header=None):
    for line in lines.iterrows():
        #print(line[1])
        if cnt == 0:
            cnt+=1
            continue
        if line[1][2] == line[1][2]:
            if line[1][0] not in snapshots:
                if len(snapshots) > 0:
                    snapshots[snapshot_id].sort()
                    #print(len(snapshots[snapshot_id]))
                    if len(snapshots[snapshot_id]) > 1:                        
                        m = abs(int(snapshots[snapshot_id][-1]) - int(snapshots[snapshot_id][0]) )
                        longevity[snapshot_id] = m
                        #print(snapshot_id,' ', longevity[snapshot_id])
                        
                        s  = pd.Series(longevity,index=longevity.keys())
                        df = pd.DataFrame(s.items(), columns=['snapshot_id', 'longevity'])
                        #print(df)
                        df.to_csv('/tmp/longevity.csv.gz', compression = 'gzip', mode ='a', header=True, index=False)
                    del snapshots[snapshot_id]
                    
                snapshot_id = line[1][0]
                snapshots[snapshot_id] = [line[1][2]]
            else:
                snapshots[snapshot_id].append(line[1][2])
# Out:
# 121   8705142
# 136   28444418
# 157   27679531
# 182   40010968
# 182   5295641
# 594   42760435
# 622   29300188
# 1062   4031374
# 1067   37265615
# 1092   154703616
# 1308   26225572
# 1606   56647899
# 1619   59942107
# 1781   42219965
# 1866   28674570
# 1910   121599103
# 1939   65834598
# 2051   86906785
# 2279   52040569
# 2495   45508013
# 2549   10800904
# 2792   76460515
# 2840   115896186
# 2886   7688762
# 2990   251090
# 3201   13477418
# 3317   52640250
# 3438   151095
# 3667   22233376
# 3679   67396253
# 4086   76503073
# 4165   143690233
# 4225   1927
# 4390   53210044
# 4630   2541614
# 4770   9221
# 4809   1203100
# 5199   84080
# 5414   192936325
# 5619   135928173
# 5738   266660
# 5909   77316654
# 5916   192334075
# 6012   125272153
# 6025   59666379
# 6138   18618765
# 6327   56163533
# 6770   450970
# 6960   147141356
# 7020   164834
# 7662   62926107
# 7762   1054
# 7877   23675092
# 8657   56852069
# 8812   34238484
# 8852   22935693
# 9178   93140771
# 9215   34951990
# 9376   22944215
# 9415   38644051
# 9438   69825537
# 9662   75852291
# 9702   14085447
# 9769   150874394
# 9778   68066252
# 9837   35683898
# 10076   25111833
# 10157   32214381
# 10262   18912198
# 10675   50287949
# 10971   156721217
# 11125   106915474
# 11189   29538524
# 11257   19153748
# 11443   24632874
# 11466   135560081
# 11530   49424232
# 11824   1336110756
# 11851   69953
# 11975   57472727
# 12116   27375049
# 12346   34311816
# 12375   77650
# 12447   89841226
# 12632   40938587
# 12978   9709
# 13120   19497659
# 13774   22943798
# 13893   4417330
# 13929   8477520
# 14548   48461292
# 14830   70526128
# 14913   39102873
# 15423   81301465
# 15938   122027345
# 15971   75166877
# 16086   64576205
# 16117   29831839
# 16151   34553245
# 16200   46159718
# 16389   82959212
# 16444   58366297
# 16961   7766341
# 16991   90401
# 17225   4075999
# 17362   355980
# 17456   77213947
# 17470   47071136
# 17518   834
# 17551   78803213
# 17634   63988197
# 17921   4907
# 18435   3020
# 18482   237016335
# 18587   99962469
# 18900   140210973
# 18911   48406327
# 19414   44408
# 19439   68700349
# 19888   87601
# 19913   44703230
# 47737   31614752
# 47878   36383824
# 48072   69802708
# 48116   75594591
# 48565   55214054
# 48652   39911098
# 48915   66293744
# 48976   79806937
# 49072   81708128
# 49099   1504
# 49327   94435851
# 49399   99227196
# 49721   65202797
# 49815   30755768
# 49828   26615066
# 49872   222611271
# 50192   41901155
# 50272   22962247
# 50468   83818028
# 50493   64802742
# 50836   128169421
# 50849   23767751
# 51062   67922447
# 51162   1725954
# 51238   517669
# 51268   106460010
# 51304   82456638
# 51525   52849510
# 51564   4746576
# 51601   67606903
# 51719   73610447
# 51971   73350172
# 52094   28420795
# 52334   1124266
# 52661   56577504
# 52846   24714291
# 53337   136022128
# 53614   41030896
# 53627   26984347
# 53712   156442694
# 53760   73116845
# 54036   68506438
# 54360   157415607
# 54405   74137858
# 54630   54402228
# 54787   11667524
# 54871   29998675
# 55123   27140983
# 55246   3709799
# 55285   5087022
# 55379   16734024
# 55510   138500998
# 55677   14196
# 55758   171904531
# 55896   50731972
# 55952   90379565
# 55988   37787
# 56016   16496575
# 56222   76170432
# 56513   3
# 56824   28574199
# 56958   89331917
# 57043   1190
# 57280   27990379
# 57289   29943627
# 57525   100413340
# 57602   18886768
# 57948   33597129
# 58620   22944576
# 58665   4931
# 58743   62188107
# 58791   137273995
# 58805   915333
# 58875   6571138
# 59048   4902
# 59226   6173
# 59289   528343
# 59811   35351097
# 59947   47999494
# 60068   26793337
# 60126   50313141
# 60174   99235333
# 60386   40401894
# 60427   53891107
# 60437   116290641
# 60949   26096
# 61474   733150
# 61927   40916035
# 62331   3120397
# 62621   75588499
# 62627   67864505
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b48b1cf25f5f> in <module>
#       5 snapshot_id = 0
#       6 for lines in pd.read_csv("/mnt/17volume/data/snapshot_revision_git.csv.gz", compression='gzip', chunksize=1000, encoding='utf-8', header=None):
# ----> 7     for line in lines.iterrows():
#       8         #print(line[1])
#       9         if cnt == 0:
#
# ~/env/lib/python3.6/site-packages/pandas/core/frame.py in iterrows(self)
#     950         klass = self._constructor_sliced
#     951         for k, v in zip(self.index, self.values):
# --> 952             s = klass(v, index=columns, name=k)
#     953             yield k, s
#     954
#
# ~/env/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     305                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     306
# --> 307                 data = SingleBlockManager(data, index, fastpath=True)
#     308
#     309         generic.NDFrame.__init__(self, data, fastpath=True)
#
# ~/env/lib/python3.6/site-packages/pandas/core/internals/managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1511
#    1512         if not isinstance(block, Block):
# -> 1513             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    1514
#    1515         self.blocks = tuple([block])
#
# ~/env/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3045         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3046
# -> 3047     return klass(values, ndim=ndim, placement=placement)
#    3048
#    3049
#
# ~/env/lib/python3.6/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#    2589     _can_hold_na = True
#    2590
# -> 2591     def __init__(self, values, placement=None, ndim=2):
#    2592         if issubclass(values.dtype.type, str):
#    2593             values = np.array(values, dtype=object)
#
# KeyboardInterrupt:
