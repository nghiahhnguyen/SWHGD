# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbs

number_of_indexes = [519, 1100, 560, 1200, 521, 1100]

# %%
randomSnapshot=pd.read_csv("/home/sv/random_snapshot.csv")
randomSnapshotLink=pd.read_csv("/home/sv/random_snapshot_urls.csv")
randomSnapshotDetails=pd.read_csv("/home/sv/random_snapshot_url_with_data.csv")
randomSnapshot= pd.merge(randomSnapshot, randomSnapshotLink, left_index=True, right_index=True)

# %%
randomSnapshotFull = pd.merge(randomSnapshot, randomSnapshotDetails, sort=True).drop_duplicates()
randomSnapshotFull = randomSnapshotFull[randomSnapshotFull['stargazers_count'].notnull()]

# %%
random_snapshot_table = pd.DataFrame()
random_snapshot_table.head()
for i in range(0,6):
    random_snap_tmp_table = pd.read_csv('/var/lib/neo4j/import/random_snapshot_part_0' + str(i) + '.csv', nrows=number_of_indexes[i], header=None)
    random_snapshot_table = random_snapshot_table.append(random_snap_tmp_table, ignore_index=True)
    
random_snapshot_table.columns = ["snapshot_id"]
random_snapshot_table
# Out:
#       snapshot_id
# 0        60066985
# 1        60076226
# 2        60028093
# 3        60081341
# 4        60049449
# 5        60059404
# 6        60052956
# 7        60046519
# 8        60032360
# 9        60025603
# 10       60077396
# 11       60065952
# 12       60079163
# 13       60033777
# 14       60025025
# 15       60083136
# 16       60073560
# 17       60081982
# 18       60037277
# 19       60079555
# 20       60051875
# 21       60073348
# 22       60080094
# 23       60053983
# 24       60056872
# 25       60058314
# 26       60084328
# 27       60069292
# 28       60038730
# 29       60041119
# ...           ...
# 4970     46558771
# 4971     47655608
# 4972     44735821
# 4973     44046240
# 4974     47871340
# 4975     47135433
# 4976     50907645
# 4977     55649714
# 4978     44730070
# 4979     47436839
# 4980     46198237
# 4981     48085484
# 4982     45198292
# 4983     47880362
# 4984     48374430
# 4985     44989425
# 4986     55475691
# 4987     48416129
# 4988     44506823
# 4989     47353159
# 4990     44635221
# 4991     44445442
# 4992     55353107
# 4993     53884311
# 4994     44890202
# 4995     46763840
# 4996     46854859
# 4997     48351666
# 4998     44923051
# 4999     49856461
#
# [5000 rows x 1 columns]

# %%
fivek_snapshot_table = pd.merge(randomSnapshotFull, random_snapshot_table, sort=True).drop_duplicates()
fivek_snapshot_table
# Out:
#       snapshot_id                                      snapshot_urls  \
# 0            4086  https://github.com/nidiatrovao/nidiatrovao.git...
# 1           13929         https://github.com/rogercodina/mediafilter
# 2           26126                https://github.com/kennethd/etcskel
# 3           54787                https://github.com/baronjon/bloccit
# 4           79745          https://github.com/dhyasama/discourse-api
# 5           81541                  https://github.com/arjunkori/Demo
# 6           82549  https://github.com/FelixWinterstein/Vivado-KMeans
# 7           90607                https://github.com/odoublewen/olidb
# 8           95413  https://github.com/diffdibb/diffdibb-backend-o...
# 9          104992             https://github.com/adamrunner/todo-app
# 10         105792                     https://github.com/ptrv/go-gpx
# 11         106158            https://github.com/raimohanska/dotfiles
# 12         115173            https://github.com/Walkersneps/snepsBot
# 13         118266  https://github.com/PositronicsLab/idyn-experim...
# 14         126600  https://github.com/tillgrallert/xslt-calendar-...
# 15         141330                   https://github.com/ovasgus/redes
# 16         142707               https://github.com/camposfa/ClimGrid
# 17         143107     https://github.com/fortune-cat/fortune-cat-iOS
# 18         147384  https://github.com/albertorios/albertorios.git...
# 19         151109          https://github.com/ivato/ivato.github.com
# 20         175359  https://github.com/aghstrategies/com.aghstrate...
# 21         182688                https://github.com/kanripo/KR6b0063
# 22         198538              https://github.com/kencordero/library
# 23         203987  https://github.com/codewalkerster/android_hard...
# 24         212125              https://github.com/vinodkadam/php-sdk
# 25         214290                     https://github.com/zsiva/jumps
# 26         214453      https://github.com/Valien/MySQL-Backup-Script
# 27         229205          https://github.com/fnegdaq/DQButtonAction
# 28         238652               https://github.com/egladman/Dotfiles
# 29         248553                   https://github.com/yh1224/yclock
# ...           ...                                                ...
# 4339     60087516  https://github.com/mesutcanalkan/Useful-Notebooks
# 4340     60087566        https://github.com/Codeminer42/cm42-central
# 4341     60087579                    https://github.com/OFTNAI/Spike
# 4342     60087597             https://github.com/RedstoneFiend/BHome
# 4343     60087736                 https://github.com/popcornmix/xbmc
# 4344     60087796                https://github.com/sjirka/SeamsEasy
# 4345     60087862          https://github.com/itnamerica/ITNSuncoast
# 4346     60087863                  https://github.com/mnewt/dotfiles
# 4347     60087879                 https://github.com/jschoormans/R4D
# 4348     60088007     https://github.com/melibela/melibela.github.io
# 4349     60088071                https://github.com/chmielu1/php-app
# 4350     60088139               https://github.com/alexiswl/poreduck
# 4351     60088239  https://github.com/NextechSystems/selectapidoc...
# 4352     60088354               https://github.com/yrodrigez/CPP-DSA
# 4353     60088422                https://github.com/stakater/Jamadar
# 4354     60088427  https://github.com/azurecitadel/azurecitadel.g...
# 4355     60088459                 https://github.com/psiinon/zaproxy
# 4356     60088629     https://github.com/minkphp/MinkSelenium2Driver
# 4357     60088670          https://github.com/zhouhuafei/shopex-sign
# 4358     60088684         https://github.com/taktik/ozone-components
# 4359     60088869           https://github.com/lurebreast/jiaobenapi
# 4360     60088887      https://github.com/keboola/db-writer-redshift
# 4361     60088916  https://github.com/codeandconspire/codeandcons...
# 4362     60088968       https://github.com/emetsger/nihms-submission
# 4363     60088986                     https://github.com/slamice/wri
# 4364     60089005  https://github.com/htlsne/mikutter-plugin-manager
# 4365     60089195  https://github.com/MicroFocus/alm-octane-cshar...
# 4366     60089330                     https://github.com/iwj/BingWow
# 4367     60089369               https://github.com/gvdenbro/dotfiles
# 4368     60089505                  https://github.com/SnoFox/SnoDots
#
#       stargazers_count  watchers_count   forks_count   subscribers_count
# 0                  0.0             0.0           0.0                 2.0
# 1                  2.0             2.0           1.0                 3.0
# 2                  1.0             1.0           0.0                 1.0
# 3                  0.0             0.0           0.0                 1.0
# 4                 32.0            32.0          29.0                 6.0
# 5                  0.0             0.0           0.0                 1.0
# 6                 43.0            43.0          21.0                 7.0
# 7                  0.0             0.0           0.0                 1.0
# 8                  1.0             1.0           0.0                 1.0
# 9                  0.0             0.0           0.0                 2.0
# 10                28.0            28.0           8.0                 1.0
# 11                 0.0             0.0           0.0                 0.0
# 12                 0.0             0.0           0.0                 1.0
# 13                 1.0             1.0           0.0                 4.0
# 14                 1.0             1.0           0.0                 4.0
# 15                 0.0             0.0           0.0                 1.0
# 16                 0.0             0.0           1.0                 1.0
# 17                 1.0             1.0           0.0                 2.0
# 18                 0.0             0.0           0.0                 1.0
# 19                 0.0             0.0           0.0                 1.0
# 20                 0.0             0.0           0.0                 3.0
# 21                 0.0             0.0           0.0                 2.0
# 22                 0.0             0.0           0.0                 1.0
# 23                 0.0             0.0           3.0                 1.0
# 24                 1.0             1.0           0.0                 1.0
# 25                 0.0             0.0           0.0                 1.0
# 26                 1.0             1.0           0.0                 1.0
# 27                 1.0             1.0           0.0                 1.0
# 28                 0.0             0.0           0.0                 1.0
# 29                 0.0             0.0           1.0                 1.0
# ...                ...             ...           ...                 ...
# 4339               0.0             0.0           0.0                 0.0
# 4340             275.0           275.0          60.0                61.0
# 4341              30.0            30.0          13.0                 7.0
# 4342               0.0             0.0           0.0                 1.0
# 4343              50.0            50.0          18.0                25.0
# 4344              18.0            18.0           9.0                 3.0
# 4345               0.0             0.0           0.0                 1.0
# 4346               4.0             4.0           1.0                 1.0
# 4347               2.0             2.0           2.0                 1.0
# 4348               0.0             0.0           0.0                 1.0
# 4349               0.0             0.0           1.0                 0.0
# 4350              12.0            12.0           1.0                 3.0
# 4351               0.0             0.0           7.0                17.0
# 4352               1.0             1.0           0.0                 2.0
# 4353              37.0            37.0           2.0                 8.0
# 4354              52.0            52.0          59.0                15.0
# 4355               7.0             7.0           3.0                 1.0
# 4356             414.0           414.0         142.0                21.0
# 4357               0.0             0.0           0.0                 0.0
# 4358               0.0             0.0           4.0                 5.0
# 4359               1.0             1.0           0.0                 1.0
# 4360               0.0             0.0           0.0                 7.0
# 4361               2.0             2.0           0.0                 1.0
# 4362               0.0             0.0           0.0                 1.0
# 4363               0.0             0.0           0.0                 1.0
# 4364               0.0             0.0           0.0                 1.0
# 4365               2.0             2.0           3.0                 3.0
# 4366               0.0             0.0           0.0                 1.0
# 4367               0.0             0.0           0.0                 1.0
# 4368               3.0             3.0           3.0                 0.0
#
# [4369 rows x 6 columns]

# %%
fivek_snapshot_table_nolink = fivek_snapshot_table.drop(columns=["snapshot_urls"])
fivek_snapshot_table_nolink
# Out:
#       snapshot_id  stargazers_count  watchers_count   forks_count  \
# 0            4086               0.0             0.0           0.0
# 1           13929               2.0             2.0           1.0
# 2           26126               1.0             1.0           0.0
# 3           54787               0.0             0.0           0.0
# 4           79745              32.0            32.0          29.0
# 5           81541               0.0             0.0           0.0
# 6           82549              43.0            43.0          21.0
# 7           90607               0.0             0.0           0.0
# 8           95413               1.0             1.0           0.0
# 9          104992               0.0             0.0           0.0
# 10         105792              28.0            28.0           8.0
# 11         106158               0.0             0.0           0.0
# 12         115173               0.0             0.0           0.0
# 13         118266               1.0             1.0           0.0
# 14         126600               1.0             1.0           0.0
# 15         141330               0.0             0.0           0.0
# 16         142707               0.0             0.0           1.0
# 17         143107               1.0             1.0           0.0
# 18         147384               0.0             0.0           0.0
# 19         151109               0.0             0.0           0.0
# 20         175359               0.0             0.0           0.0
# 21         182688               0.0             0.0           0.0
# 22         198538               0.0             0.0           0.0
# 23         203987               0.0             0.0           3.0
# 24         212125               1.0             1.0           0.0
# 25         214290               0.0             0.0           0.0
# 26         214453               1.0             1.0           0.0
# 27         229205               1.0             1.0           0.0
# 28         238652               0.0             0.0           0.0
# 29         248553               0.0             0.0           1.0
# ...           ...               ...             ...           ...
# 4339     60087516               0.0             0.0           0.0
# 4340     60087566             275.0           275.0          60.0
# 4341     60087579              30.0            30.0          13.0
# 4342     60087597               0.0             0.0           0.0
# 4343     60087736              50.0            50.0          18.0
# 4344     60087796              18.0            18.0           9.0
# 4345     60087862               0.0             0.0           0.0
# 4346     60087863               4.0             4.0           1.0
# 4347     60087879               2.0             2.0           2.0
# 4348     60088007               0.0             0.0           0.0
# 4349     60088071               0.0             0.0           1.0
# 4350     60088139              12.0            12.0           1.0
# 4351     60088239               0.0             0.0           7.0
# 4352     60088354               1.0             1.0           0.0
# 4353     60088422              37.0            37.0           2.0
# 4354     60088427              52.0            52.0          59.0
# 4355     60088459               7.0             7.0           3.0
# 4356     60088629             414.0           414.0         142.0
# 4357     60088670               0.0             0.0           0.0
# 4358     60088684               0.0             0.0           4.0
# 4359     60088869               1.0             1.0           0.0
# 4360     60088887               0.0             0.0           0.0
# 4361     60088916               2.0             2.0           0.0
# 4362     60088968               0.0             0.0           0.0
# 4363     60088986               0.0             0.0           0.0
# 4364     60089005               0.0             0.0           0.0
# 4365     60089195               2.0             2.0           3.0
# 4366     60089330               0.0             0.0           0.0
# 4367     60089369               0.0             0.0           0.0
# 4368     60089505               3.0             3.0           3.0
#
#        subscribers_count
# 0                    2.0
# 1                    3.0
# 2                    1.0
# 3                    1.0
# 4                    6.0
# 5                    1.0
# 6                    7.0
# 7                    1.0
# 8                    1.0
# 9                    2.0
# 10                   1.0
# 11                   0.0
# 12                   1.0
# 13                   4.0
# 14                   4.0
# 15                   1.0
# 16                   1.0
# 17                   2.0
# 18                   1.0
# 19                   1.0
# 20                   3.0
# 21                   2.0
# 22                   1.0
# 23                   1.0
# 24                   1.0
# 25                   1.0
# 26                   1.0
# 27                   1.0
# 28                   1.0
# 29                   1.0
# ...                  ...
# 4339                 0.0
# 4340                61.0
# 4341                 7.0
# 4342                 1.0
# 4343                25.0
# 4344                 3.0
# 4345                 1.0
# 4346                 1.0
# 4347                 1.0
# 4348                 1.0
# 4349                 0.0
# 4350                 3.0
# 4351                17.0
# 4352                 2.0
# 4353                 8.0
# 4354                15.0
# 4355                 1.0
# 4356                21.0
# 4357                 0.0
# 4358                 5.0
# 4359                 1.0
# 4360                 7.0
# 4361                 1.0
# 4362                 1.0
# 4363                 1.0
# 4364                 1.0
# 4365                 3.0
# 4366                 1.0
# 4367                 1.0
# 4368                 0.0
#
# [4369 rows x 5 columns]

# %%
longevity_table = pd.DataFrame()
for i in range(97,97+6):
    tmp_longevity_table = pd.read_csv('/home/sv/longevity-a'+ chr(i) +'.csv.gz', encoding='utf-8', header=None, chunksize=10000, compression='gzip')
    tmp_longevity_table = pd.concat(tmp_longevity_table, ignore_index=True)
    tmp_longevity_table.columns = ["snapshot_id","longevity"]
    input_data = pd.merge(tmp_longevity_table, random_snapshot_table, sort=True).drop_duplicates()
    longevity_table = longevity_table.append(input_data, ignore_index=True)
    
longevity_table
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-3922cf3d634a> in <module>()
#       2 for i in range(97,97+6):
#       3     tmp_longevity_table = pd.read_csv('/home/sv/longevity-a'+ chr(i) +'.csv.gz', encoding='utf-8', header=None, chunksize=10000, compression='gzip')
# ----> 4     tmp_longevity_table = pd.concat(tmp_longevity_table, ignore_index=True)
#       5     tmp_longevity_table.columns = ["snapshot_id","longevity"]
#       6     input_data = pd.merge(tmp_longevity_table, random_snapshot_table, sort=True).drop_duplicates()
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/core/reshape/concat.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/core/reshape/concat.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     257             objs = [objs[k] for k in keys]
#     258         else:
# --> 259             objs = list(objs)
#     260
#     261         if len(objs) == 0:
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/io/common.pyc in <lambda>(self)
#      71
#      72 if not compat.PY3:
# ---> 73     BaseIterator.next = lambda self: self.__next__()
#      74
#      75
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/io/parsers.pyc in __next__(self)
#    1113     def __next__(self):
#    1114         try:
# -> 1115             return self.get_chunk()
#    1116         except StopIteration:
#    1117             self.close()
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/io/parsers.pyc in get_chunk(self, size)
#    1171                 raise StopIteration
#    1172             size = min(size, self.nrows - self._currow)
# -> 1173         return self.read(nrows=size)
#    1174
#    1175
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# KeyboardInterrupt:

# %%
cycle_time_table = pd.DataFrame()
for i in range(97,97+6):
    tmp_cycle_time_table = pd.read_csv('/home/sv/cycle_time_release_a'+ chr(i) +'.csv.gz', encoding='utf-8', header=None, chunksize=10000, compression='gzip')
    tmp_cycle_time_table = pd.concat(tmp_cycle_time_table, ignore_index=True)
    tmp_cycle_time_table.columns = ["snapshot_id","avg_cycle_time"]
    input_data = pd.merge(tmp_cycle_time_table, random_snapshot_table, sort=True).drop_duplicates()
    cycle_time_table = cycle_time_table.append(input_data, ignore_index=True)
    
cycle_time_table
