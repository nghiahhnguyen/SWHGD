# %%
import csv
from dateutil.parser import parse
from decimal import *
import pandas as pd
import gc
import os
from multiprocessing import Process
def intersection(list1, list2):
    res = []
    idx1 = 0
    while idx1 < len(list1):
        if list1[idx1] in list2:
            res.append(list1[idx1])
        idx1 += 1
    return res

def get_project_info(name):
    info(name)
    snapshots = {}
    snapshot_id = 0
    one_day = 86400
    one_week = 604800
    one_month = 2628000
    cnt = 0
    for lines in pd.read_csv('/mnt/17volume/data/odoo.csv', encoding='utf-8', header=None, chunksize=1000000):
        for line in lines.iterrows():
            if line[1][0] not in snapshots:
                if len(snapshots) > 0:
                snapshots = {}
                snapshot_id = line[1][0]
                if line[1][0] == line[1][0]:
                    print('new snapshot:', snapshot_id)
                    snapshots[line[1][0]] = [[int(line[1][2]), int(line[1][3])]]
            else:
                snapshots[line[1][0]].append([int(line[1][2]), int(line[1][3])])
    

    #do for the last one
    if len(snapshots) > 0:
        print("The fucking last snapshot:", snapshot_id)
        snapshots[snapshot_id].sort(key=lambda x: x[0])
        min_date = snapshots[snapshot_id][0][0]
        max_date = snapshots[snapshot_id][-1][0]
        if max_date-min_date >= 7890000:
            print('start extracting snapshot:', snapshot_id)
            total_commits = 0
            authors = []

            daily_cnt = 1
            daily_commits = []
            daily_contributors = []
            daily_temp_contrib = []

            weekly_cnt = 1
            weekly_commits = []
            weekly_contributors = []
            weekly_temp_contrib = []

            monthly_cnt = 1
            monthly_commits = []
            monthly_contributors = []
            monthly_temp_contrib = []

            for _, rev in enumerate(snapshots[snapshot_id]):
                total_commits += 1
                if rev[1] not in authors:
                    authors.append(rev[1])

                #daily
                if rev[1] not in daily_contributors and rev[0] <= min_date + one_day:
                    daily_contributors.append(rev[1])
                if rev[0] <= min_date + one_day*daily_cnt:
                    if rev[1] not in daily_temp_contrib:
                        daily_temp_contrib.append(rev[1])
                else:
                    daily_contributors = intersection(daily_contributors, daily_temp_contrib)
                    daily_temp_contrib = []
                    daily_cnt += 1
                    while rev[0] > min_date + one_day*daily_cnt:
                        daily_commits.append(0)
                        daily_contributors = []
                        daily_cnt += 1
                    daily_temp_contrib.append(rev[1])
                    daily_commits.append(1)

                #weekly
                if rev[1] not in weekly_contributors and rev[0] <= min_date + one_week:
                    weekly_contributors.append(rev[1])
                if rev[0] <= min_date + one_week*weekly_cnt:
                    if rev[1] not in weekly_temp_contrib:
                        weekly_temp_contrib.append(rev[1])
                else:
                    weekly_contributors = intersection(weekly_contributors, weekly_temp_contrib)
                    weekly_temp_contrib = []
                    weekly_cnt += 1
                    while rev[0] > min_date + one_week*weekly_cnt:
                        weekly_commits.append(0)
                        weekly_contributors = []
                        weekly_cnt += 1
                    weekly_temp_contrib.append(rev[1])
                    weekly_commits.append(1)

                #monthly
                if rev[1] not in monthly_contributors and rev[0] <= min_date + one_month:
                    monthly_contributors.append(rev[1])
                if rev[0] <= min_date + one_month*monthly_cnt:
                    if rev[1] not in monthly_temp_contrib:
                        monthly_temp_contrib.append(rev[1])
                else:
                    monthly_contributors = intersection(monthly_contributors, monthly_temp_contrib)
                    monthly_temp_contrib = []
                    monthly_cnt += 1
                    while rev[0] > min_date + one_month*monthly_cnt:
                        monthly_commits.append(0)
                        monthly_contributors = []
                        monthly_cnt += 1
                    monthly_temp_contrib.append(rev[1])
                    monthly_commits.append(1)

            if len(daily_commits) == 0:
                daily_commits.append(1)
            if len(weekly_commits) == 0:
                weekly_commits.append(1)
            if len(monthly_commits) == 0:
                monthly_commits.append(1)
            daily_freq = Decimal(sum(daily_commits))/Decimal(len(daily_commits))
            weekly_freq = Decimal(sum(weekly_commits))/Decimal(len(weekly_commits))
            monthly_freq = Decimal(sum(monthly_commits))/Decimal(len(monthly_commits))
            df = pd.DataFrame({
                'snapshot_id': [snapshot_id],
                'total_commits': [total_commits],
                'total_authors': [len(authors)],
                'daily_freq': [daily_freq],
                'daily_contributors': [len(daily_contributors)],
                'weekly_freq': [weekly_freq],
                'weekly_contributors': [len(weekly_contributors)],
                'monthly_freq': [monthly_freq],
                'monthly_contributors': [len(monthly_contributors)]
            })
            df.to_csv('/home/sv/odoo_metric.csv', mode = 'w', header = False, index = False)
            print('done writing snapshot:', snapshot_id)
            del daily_commits
            del daily_contributors
            del daily_temp_contrib
            del weekly_commits
            del weekly_contributors
            del weekly_temp_contrib
            del monthly_commits
            del monthly_contributors
            del monthly_temp_contrib
        del snapshots
        gc.collect()
def info(title):
    print(title)
    print('module name:', __name__)
    print('parent process:', os.getppid())
    print('process id:', os.getpid())
if __name__ == '__main__': 
    get_project_info('')
# Out:
# ('module name:', '__main__')
# ('parent process:', 14524)
# ('process id:', 31453)
# ('new snapshot:', 30491295)
# ('The fucking last snapshot:', 30491295)
# ('start extracting snapshot:', 30491295)
# ('done writing snapshot:', 30491295)
# ('new snapshot:', 43979281)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-91b0dbccfdee> in <module>()
#     270     print('process id:', os.getpid())
#     271 if __name__ == '__main__':
# --> 272     get_project_info('')
#
# <ipython-input-3-91b0dbccfdee> in get_project_info(name)
#      24     cnt = 0
#      25     for lines in pd.read_csv('/mnt/17volume/data/final.csv', encoding='utf-8', header=None, chunksize=1000000):
# ---> 26         for line in lines.iterrows():
#      27             if line[1][0] not in snapshots:
#      28                 if len(snapshots) > 0:
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in iterrows(self)
#     844         klass = self._constructor_sliced
#     845         for k, v in zip(self.index, self.values):
# --> 846             s = klass(v, index=columns, name=k)
#     847             yield k, s
#     848
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/core/series.pyc in __init__(self, data, index, dtype, name, copy, fastpath)
#     260             else:
#     261                 data = sanitize_array(data, index, dtype, copy,
# --> 262                                       raise_cast_failure=True)
#     263
#     264                 data = SingleBlockManager(data, index, fastpath=True)
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.pyc in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     580
#     581             # we will try to copy be-definition here
# --> 582             subarr = _try_cast(data, True, dtype, copy, raise_cast_failure)
#     583
#     584     elif isinstance(data, ExtensionArray):
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/core/internals/construction.pyc in _try_cast(arr, take_fast_path, dtype, copy, raise_cast_failure)
#     702                                        isinstance(subarr, np.ndarray))):
#     703             subarr = construct_1d_object_array_from_listlike(subarr)
# --> 704         elif not is_extension_type(subarr):
#     705             subarr = construct_1d_ndarray_preserving_na(subarr, dtype,
#     706                                                         copy=copy)
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/common.pyc in is_extension_type(arr)
#    1695     elif is_sparse(arr):
#    1696         return True
# -> 1697     elif is_datetime64tz_dtype(arr):
#    1698         return True
#    1699     return False
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/common.pyc in is_datetime64tz_dtype(arr_or_dtype)
#     467     if arr_or_dtype is None:
#     468         return False
# --> 469     return DatetimeTZDtype.is_dtype(arr_or_dtype)
#     470
#     471
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/base.pyc in is_dtype(cls, dtype)
#      99
#     100         if isinstance(dtype, (ABCSeries, ABCIndexClass,
# --> 101                               ABCDataFrame, np.dtype)):
#     102             # https://github.com/pandas-dev/pandas/issues/22960
#     103             # avoid passing data to `construct_from_string`. This could
#
# /home/sv/.local/lib/python2.7/site-packages/pandas/core/dtypes/generic.pyc in _check(cls, inst)
#       5 # objects
#       6 def create_pandas_abc_type(name, attr, comp):
# ----> 7     @classmethod
#       8     def _check(cls, inst):
#       9         return getattr(inst, attr, '_typ') in comp
#
# KeyboardInterrupt:
